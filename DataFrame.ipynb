# %%
import pandas as pd

df=pd.read_csv('data/loan.csv')

# %%
df.value_counts(dropna=True) #dropna=False 결측값도 표기
# Out:
# loan_id  married_or_not  self_employed_or_not  applicant_income  loan_amount  property_area  loan_status
# LP1003   Y               N                     4583              128.4        Rural          N              1
# LP2332   Y               N                     2253              110.5        Rural          Y              1
# LP2308   Y               N                     2167              115.9        City           Y              1
# LP2314   N               N                     2213              66.0         Rural          Y              1
# LP2315   Y               N                     8300              152.1        Suburb         N              1
#                                                                                                            ..
# LP1674   Y               N                     2600              90.7         Suburb         Y              1
# ...

# %%
type(df['loan_amount'])
df
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 0    LP1003              Y                    N              4583
# 1    LP1005              Y                    Y              3000
# 2    LP1006              Y                    N              2583
# 3    LP1008              N                    N              6000
# 4    LP1011              Y                    Y              5417
# ..      ...            ...                  ...               ...
# 595  LP2974              Y                    N              3232
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
# 599  LP2990              N                    Y              4583
#
#      loan_amount property_area loan_status
# 0          128.4         Rural           N
# 1           66.0          City           Y
# ...

# %%
df['property_area'].value_counts(dropna=False,  normalize=True)
# Out:
# property_area
# Suburb    0.380000
# City      0.328333
# Rural     0.291667
# Name: proportion, dtype: float64

# %%
condition1 = df['married_or_not'] == 'Y'

# %%
m = df['applicant_income'].mean()
condition2 = df['applicant_income'] > m

# %%
condition3 = df['property_area'] == 'City'

# %%
df[condition1 | (condition2 & condition3)]
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 0    LP1003              Y                    N              4583
# 1    LP1005              Y                    Y              3000
# 2    LP1006              Y                    N              2583
# 3    LP1008              N                    N              6000
# 4    LP1011              Y                    Y              5417
# ..      ...            ...                  ...               ...
# 594  LP2964              Y                    N              3987
# 595  LP2974              Y                    N              3232
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
#
#      loan_amount property_area loan_status
# 0          128.4         Rural           N
# 1           66.0          City           Y
# ...

# %%
condition1 = df['loan_status'] == 'Y'

# %%
condition2 = df['self_employed_or_not'] == 'N'

# %%
condition3 = df['applicant_income'] > df['applicant_income'].median()

# %%
df['applicant_income'].median()
# Out:
# 3806.0

# %%
group1 = df[condition1 & condition2 & condition3]

# %%
group1
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 3    LP1008              N                    N              6000
# 7    LP1018              Y                    N              4006
# 14   LP1032              N                    N              4950
# 20   LP1046              Y                    N              5955
# 26   LP1073              Y                    N              4226
# ..      ...            ...                  ...               ...
# 591  LP2959              Y                    N             12000
# 594  LP2964              Y                    N              3987
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
#
#      loan_amount property_area loan_status
# 3          141.4          City           Y
# 7          168.6          City           Y
# ...

# %%
df.query('applicant_income > 10000')
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 8    LP1020              Y                    N             12841
# 33   LP1100              N                    N             12500
# 52   LP1186              Y                    Y             11500
# 65   LP1233              Y                    N             10750
# 100  LP1369              Y                    N             11417
# 108  LP1401              Y                    N             14583
# 112  LP1422              N                    N             10408
# 119  LP1448              Y                    N             23803
# 120  LP1451              Y                    Y             10513
# 122  LP1469              N                    Y             20166
# 130  LP1492              N                    N             14999
# 136  LP1508              Y                    N             11757
# 138  LP1516              Y                    N             14866
# ...

# %%
query1 = df.query('married_or_not == "Y" & applicant_income >= applicant_income.mean()')
query1
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 4    LP1011              Y                    Y              5417
# 8    LP1020              Y                    N             12841
# 19   LP1043              Y                    N              7660
# 20   LP1046              Y                    N              5955
# 24   LP1066              Y                    Y              9560
# ..      ...            ...                  ...               ...
# 586  LP2948              Y                    N              5780
# 589  LP2953              Y                    N              5703
# 591  LP2959              Y                    N             12000
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
#
#      loan_amount property_area loan_status
# 4          267.4          City           Y
# 8          349.3        Suburb           N
# ...

# %%
df['applicant_income'].mean()
# Out:
# 5412.161666666667

# %%
query1['applicant_income'].min()
# Out:
# 5417

# %%
df
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 0    LP1003              Y                    N              4583
# 1    LP1005              Y                    Y              3000
# 2    LP1006              Y                    N              2583
# 3    LP1008              N                    N              6000
# 4    LP1011              Y                    Y              5417
# ..      ...            ...                  ...               ...
# 595  LP2974              Y                    N              3232
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
# 599  LP2990              N                    Y              4583
#
#      loan_amount property_area loan_status
# 0          128.4         Rural           N
# 1           66.0          City           Y
# ...

# %%
df.drop('loan_status', axis=1)
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 0    LP1003              Y                    N              4583
# 1    LP1005              Y                    Y              3000
# 2    LP1006              Y                    N              2583
# 3    LP1008              N                    N              6000
# 4    LP1011              Y                    Y              5417
# ..      ...            ...                  ...               ...
# 595  LP2974              Y                    N              3232
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
# 599  LP2990              N                    Y              4583
#
#      loan_amount property_area
# 0          128.4         Rural
# 1           66.0          City
# 2          120.5          City
# 3          141.4          City
# ...

# %%
airbnb_df = pd.read_csv('data/airbnb.csv')

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  MASSACHUSETTS       4     1     Apartment     NaN          0
# 2    OZ5857       ILLINOIS       4     3     Apartment   100.0         51
# 3    HY8797     california       2     1     Apartment    75.0          4
# 4    VN7858  massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     california       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       ILLINOIS       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price
# ...

# %%
airbnb_df.isna().sum()
# Out:
# id                0
# state             0
# guests            0
# beds              0
# property_type     0
# rating           13
# n_reviews         0
# location          0
# price             0
# dtype: int64

# %%
null_df = airbnb_df[airbnb_df.isna().any(axis=1)]
print(null_df)
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 1    DB7921  MASSACHUSETTS       4     1     Apartment     NaN          0
# 127  MB7199       Illinois       2     1     Apartment     NaN          0
# 189  DE6323       illinois       2     1   Condominium     NaN          0
# 206  ME5527       ILLINOIS       2     1         House     NaN          0
# 272  RM9271       illinois       2     1     Apartment     NaN          0
# 275  TA9777     California       2     1   Condominium     NaN          0
# 366  LP6045       ILLINOIS       2     1     Apartment     NaN          0
# 534  DC4208       ILLINOIS       5     3         House     NaN          0
# 546  IE7576       illinois       1     1         House     NaN          0
# 552  DY9962     California       1     1   Condominium     NaN          0
# 586  UW2000     California       8     1         Other     NaN          0
# 594  VM7350       ILLINOIS       2     1     Apartment     NaN          0
# ...

# %%
cell_df = pd.read_csv('data/cellphone.csv')

# %%
cell_df
# Out:
#       brand                                        name  size   price  \
# 0     apple                           iPhone 14 (128GB)  6.1"  1250.0
# 1     apple                           iPhone 14 (256GB)  6.1"  1400.0
# 2     Apple                           iPhone 14 (512GB)  6.1"  1700.0
# 3     apple                      iPhone 14 Plus (128GB)  6.7"  1350.0
# 4     APPLE                      iPhone 14 Plus (256GB)  6.7"  1500.0
# ..      ...                                         ...   ...     ...
# 65  SAMSUNG                    Galaxy S20 Ultra (512GB)  6.9"  1793.0
# 66  samsung                         Galaxy S20+ (256GB)  6.7"  1353.0
# 67  SAMSUNG                      Galaxy Z Flip2 (256GB)  6.7"  1650.0
# 68  Samsung                      Galaxy Z Fold2 (256GB)  7.6"  1892.0
# 69  samsung  Galaxy Z Fold2 Thom Browne Edition (256GB)  7.6"  3960.0
#
#     battery  weight  year
# 0      3729   172.0  2022
# 1      3729   172.0  2022
# 2      3729   172.0  2022
# ...

# %%
cell_df[cell_df.isna().any(axis=1)]
# Out:
#     brand                    name  size   price  battery  weight  year
# 37  Apple  iPhone 13 mini (128GB)  5.4"   950.0     2406     NaN  2021
# 38  Apple  iPhone 13 mini (256GB)  5.4"  1090.0     2406     NaN  2021
# 39  APPLE  iPhone 13 mini (512GB)  5.4"  1360.0     2406     NaN  2021

# %%
cell_df.dropna()
# Out:
#       brand                                        name  size   price  \
# 0     apple                           iPhone 14 (128GB)  6.1"  1250.0
# 1     apple                           iPhone 14 (256GB)  6.1"  1400.0
# 2     Apple                           iPhone 14 (512GB)  6.1"  1700.0
# 3     apple                      iPhone 14 Plus (128GB)  6.7"  1350.0
# 4     APPLE                      iPhone 14 Plus (256GB)  6.7"  1500.0
# ..      ...                                         ...   ...     ...
# 65  SAMSUNG                    Galaxy S20 Ultra (512GB)  6.9"  1793.0
# 66  samsung                         Galaxy S20+ (256GB)  6.7"  1353.0
# 67  SAMSUNG                      Galaxy Z Flip2 (256GB)  6.7"  1650.0
# 68  Samsung                      Galaxy Z Fold2 (256GB)  7.6"  1892.0
# 69  samsung  Galaxy Z Fold2 Thom Browne Edition (256GB)  7.6"  3960.0
#
#     battery  weight  year
# 0      3729   172.0  2022
# 1      3729   172.0  2022
# 2      3729   172.0  2022
# ...

# %%
mean = cell_df['weight'].mean()

# %%
cell_df['weight'] = cell_df['weight'].fillna(mean)

# %%
cell_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   brand    70 non-null     object
#  1   name     70 non-null     object
#  2   size     70 non-null     object
#  3   price    70 non-null     float64
#  4   battery  70 non-null     int64
#  5   weight   70 non-null     float64
#  6   year     70 non-null     int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.0+ KB

# %%
airbnb_df.duplicated(subset='id', keep=False) # keep=first, last, False 등으로 조건이 있는데 first는 첫번째는 중복을 false로 놓고 그다음부터 True last는 반대
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 708    False
# 709    False
# 710    False
# 711    False
# 712    False
# Length: 713, dtype: bool

# %%
cell_df_tmp = cell_df.duplicated(subset='name')
cell_df[cell_df_tmp]
# Out:
#       brand                       name  size   price  battery  weight  year
# 19  samsung        Galaxy S22+ (256GB)  6.6"  1199.0     4500   195.0  2022
# 23  samsung     Galaxy Z Fold4 (256GB)  7.6"  1998.7     4400   263.0  2022
# 56    apple  iPhone 12 Pro Max (128GB)  6.7"  1490.0     3687   228.0  2020
# 57    apple  iPhone 12 Pro Max (128GB)  6.7"  1490.0     3687   228.0  2020

# %%
cell_df
# Out:
#       brand                                        name  size   price  \
# 0     apple                           iPhone 14 (128GB)  6.1"  1250.0
# 1     apple                           iPhone 14 (256GB)  6.1"  1400.0
# 2     Apple                           iPhone 14 (512GB)  6.1"  1700.0
# 3     apple                      iPhone 14 Plus (128GB)  6.7"  1350.0
# 4     APPLE                      iPhone 14 Plus (256GB)  6.7"  1500.0
# ..      ...                                         ...   ...     ...
# 65  SAMSUNG                    Galaxy S20 Ultra (512GB)  6.9"  1793.0
# 66  samsung                         Galaxy S20+ (256GB)  6.7"  1353.0
# 67  SAMSUNG                      Galaxy Z Flip2 (256GB)  6.7"  1650.0
# 68  Samsung                      Galaxy Z Fold2 (256GB)  7.6"  1892.0
# 69  samsung  Galaxy Z Fold2 Thom Browne Edition (256GB)  7.6"  3960.0
#
#     battery  weight  year
# 0      3729   172.0  2022
# 1      3729   172.0  2022
# 2      3729   172.0  2022
# ...

# %%
cell_df[cell_df.duplicated(keep=False)]
# Out:
#       brand                       name  size   price  battery  weight  year
# 18  samsung        Galaxy S22+ (256GB)  6.6"  1199.0     4500   195.0  2022
# 19  samsung        Galaxy S22+ (256GB)  6.6"  1199.0     4500   195.0  2022
# 22  samsung     Galaxy Z Fold4 (256GB)  7.6"  1998.7     4400   263.0  2022
# 23  samsung     Galaxy Z Fold4 (256GB)  7.6"  1998.7     4400   263.0  2022
# 55    apple  iPhone 12 Pro Max (128GB)  6.7"  1490.0     3687   228.0  2020
# 56    apple  iPhone 12 Pro Max (128GB)  6.7"  1490.0     3687   228.0  2020
# 57    apple  iPhone 12 Pro Max (128GB)  6.7"  1490.0     3687   228.0  2020

# %%
cell_df.drop_duplicates(keep='first')
# Out:
#       brand                                        name  size   price  \
# 0     apple                           iPhone 14 (128GB)  6.1"  1250.0
# 1     apple                           iPhone 14 (256GB)  6.1"  1400.0
# 2     Apple                           iPhone 14 (512GB)  6.1"  1700.0
# 3     apple                      iPhone 14 Plus (128GB)  6.7"  1350.0
# 4     APPLE                      iPhone 14 Plus (256GB)  6.7"  1500.0
# ..      ...                                         ...   ...     ...
# 65  SAMSUNG                    Galaxy S20 Ultra (512GB)  6.9"  1793.0
# 66  samsung                         Galaxy S20+ (256GB)  6.7"  1353.0
# 67  SAMSUNG                      Galaxy Z Flip2 (256GB)  6.7"  1650.0
# 68  Samsung                      Galaxy Z Fold2 (256GB)  7.6"  1892.0
# 69  samsung  Galaxy Z Fold2 Thom Browne Edition (256GB)  7.6"  3960.0
#
#     battery  weight  year
# 0      3729   172.0  2022
# 1      3729   172.0  2022
# 2      3729   172.0  2022
# ...

# %%
drop_brand = cell_df.drop_duplicates(subset='brand')
drop_name = cell_df.drop_duplicates(subset='name')
drop_price = cell_df.drop_duplicates(subset='price')
# Out:
#       brand                                        name  size   price  \
# 0     apple                           iPhone 14 (128GB)  6.1"  1250.0
# 1     apple                           iPhone 14 (256GB)  6.1"  1400.0
# 2     Apple                           iPhone 14 (512GB)  6.1"  1700.0
# 3     apple                      iPhone 14 Plus (128GB)  6.7"  1350.0
# 4     APPLE                      iPhone 14 Plus (256GB)  6.7"  1500.0
# 5     Apple                      iPhone 14 Plus (512GB)  6.7"  1800.0
# 6     APPLE                       iPhone 14 Pro (128GB)  6.1"  1550.0
# 8     APPLE                       iPhone 14 Pro (512GB)  6.1"  2000.0
# 9     APPLE                         iPhone 14 Pro (1TB)  6.1"  2300.0
# 10    apple                   iPhone 14 Pro Max (128GB)  6.7"  1740.0
# 11    apple                   iPhone 14 Pro Max (256GB)  6.7"  1900.0
# 12    apple                   iPhone 14 Pro Max (512GB)  6.7"  2200.0
# ...

# %%
cell_df_tmp
# Out:
#       brand                      name  size   price  battery  weight  year
# 0     apple         iPhone 14 (128GB)  6.1"  1250.0     3729   172.0  2022
# 2     Apple         iPhone 14 (512GB)  6.1"  1700.0     3729   172.0  2022
# 4     APPLE    iPhone 14 Plus (256GB)  6.7"  1500.0     4325   203.0  2022
# 14  SAMSUNG        Galaxy S22 (256GB)  6.1"   999.9     3700   167.0  2022
# 16  samsung  Galaxy S22 Ultra (512GB)  6.8"  1551.0     5000   228.0  2022
# 20  Samsung    Galaxy Z Flip4 (256GB)  6.7"  1353.0     3700   187.0  2022

# %%
iqr = cell_df['price'].quantile(0.75) - cell_df['price'].quantile(0.25)

# %%
q1 = cell_df['price'].quantile(0.25)
q2 = cell_df['price'].quantile(0.75)

# %%
max = q2 + 1.5 * iqr
min = q1 - 1.5 * iqr
one_df = (cell_df['price'] < max) & (cell_df['price'] > min)

# %%
airbnb_df['location'].str.split(',').str[0]
# Out:
# 0           Avondale
# 1          South End
# 2           Avondale
# 3               SoMa
# 4       West Roxbury
#            ...
# 708           Venice
# 709     Mid-Wilshire
# 710    Redondo Beach
# 711         Lakeview
# 712      East Boston
# Name: location, Length: 713, dtype: object

# %%
airbnb_df.drop(columns='location', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [174], line 1
# ----> 1 airbnb_df.drop(columns='location', inplace=True)
#
# File c:\Users\kangdongwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
airbnb_df.replace("Apartment", "Apart", regex=True) #regex=True 정규 표현식으로 비슷한 단어들도 다 바꿔줌 ex)Apartments -> Aparts
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1         Apart    96.0         55
# 1    DB7921  MASSACHUSETTS       4     1         Apart     NaN          0
# 2    OZ5857       ILLINOIS       4     3         Apart   100.0         51
# 3    HY8797     california       2     1         Apart    75.0          4
# 4    VN7858  massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1         Apart    97.0         60
# 709  ZR5298     california       4     2         Apart    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       ILLINOIS       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1         Apart    96.0         61
#
#      price
# 0       48
# 1      115
# 2      150
# 3      125
# 4       64
# ...

# %%
patient_df=pd.read_csv('data/patient.csv')

# %%
patient_df['waist_hip_ratio'] = patient_df['waist'] / patient_df['hip']

# %%
patient_df['waist_hip_ratio'] = round(patient_df['waist'] / patient_df['hip'], 2)

# %%
patient_df
# Out:
#      age     sex  glucose  cholesterol  height  weight  hip  waist diabetes  \
# 0     50    Male      385          140    1.75    78.0   41     37        Y
# 1     37  Female       67          214    1.63    65.8   42     34        N
# 2     43  Female      100          160    1.63    63.5   40     37        N
# 3     32  Female       90          176    1.60   114.3   58     45        N
# 4     20    Male       71          164    1.83    65.8   36     29        N
# ..   ...     ...      ...          ...     ...     ...  ...    ...      ...
# 343   40    Male       87          218    1.85    90.7   41     38        N
# 344   66    Male      174          188    1.73    95.3   48     45        N
# 345   31  Female       69          183    1.68    86.2   47     41        N
# 346   44    Male       84          202    1.73    71.2   37     33        N
# 347   40  Female       85          169    1.65    81.6   44     40        N
#
#      waist_hip_ratio
# 0               0.90
# ...

# %%
cell_df
# Out:
#       brand                                        name  size  price  battery  \
# 0     apple                           iPhone 14 (128GB)  6.1"  False     3729
# 1     apple                           iPhone 14 (256GB)  6.1"  False     3729
# 2     Apple                           iPhone 14 (512GB)  6.1"  False     3729
# 3     apple                      iPhone 14 Plus (128GB)  6.7"  False     4325
# 4     APPLE                      iPhone 14 Plus (256GB)  6.7"  False     4325
# ..      ...                                         ...   ...    ...      ...
# 65  SAMSUNG                    Galaxy S20 Ultra (512GB)  6.9"  False     5000
# 66  samsung                         Galaxy S20+ (256GB)  6.7"  False     4500
# 67  SAMSUNG                      Galaxy Z Flip2 (256GB)  6.7"  False     3300
# 68  Samsung                      Galaxy Z Fold2 (256GB)  7.6"  False     4500
# 69  samsung  Galaxy Z Fold2 Thom Browne Edition (256GB)  7.6"  False     4500
#
#     weight  year
# ...

# %%
# cell_df['brand'] = cell_df['brand'].str.capitalize()
# cell_df['model'] = cell_df['name'].str.split('(').str[0]
# cell_df['capacity'] = cell_df['name'].str.split('(').str[1]
# cell_df['capacity'] = cell_df['capacity'].str.replace(')', '')
# cell_df['size'] = cell_df['size'].str.replace('"', "")
# cell_df.drop(columns='name', inplace=True)
# cell_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kangdongwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\kangdongwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\kangdongwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# ...

# %%
patient_df['age_group'] = pd.cut(patient_df['age'], bins=[20,30,40,50,60,70], right=False)

# %%
patient_df
# Out:
#      age     sex  glucose  cholesterol  height  weight  hip  waist diabetes  \
# 0     50    Male      385          140    1.75    78.0   41     37        Y
# 1     37  Female       67          214    1.63    65.8   42     34        N
# 2     43  Female      100          160    1.63    63.5   40     37        N
# 3     32  Female       90          176    1.60   114.3   58     45        N
# 4     20    Male       71          164    1.83    65.8   36     29        N
# ..   ...     ...      ...          ...     ...     ...  ...    ...      ...
# 343   40    Male       87          218    1.85    90.7   41     38        N
# 344   66    Male      174          188    1.73    95.3   48     45        N
# 345   31  Female       69          183    1.68    86.2   47     41        N
# 346   44    Male       84          202    1.73    71.2   37     33        N
# 347   40  Female       85          169    1.65    81.6   44     40        N
#
#      waist_hip_ratio age_group
# ...

# %%
patient_df['bmi'] = patient_df['weight'] / patient_df['height'] ** 2
patient_df['obesity'] = [
    'under' if x < 18.5 else 
    'healthy' if x < 25 else 
    'over' if x < 30 else 
    'obese' 
    for x in patient_df['bmi']
]
patient_df

#pd.cut(bins = [18.5, 25, 30], labels = ['under', 'healthy', 'over', 'obese']써도 됨
# Out:
#      age     sex  glucose  cholesterol  height  weight  hip  waist diabetes  \
# 0     50    Male      385          140    1.75    78.0   41     37        Y
# 1     37  Female       67          214    1.63    65.8   42     34        N
# 2     43  Female      100          160    1.63    63.5   40     37        N
# 3     32  Female       90          176    1.60   114.3   58     45        N
# 4     20    Male       71          164    1.83    65.8   36     29        N
# ..   ...     ...      ...          ...     ...     ...  ...    ...      ...
# 343   40    Male       87          218    1.85    90.7   41     38        N
# 344   66    Male      174          188    1.73    95.3   48     45        N
# 345   31  Female       69          183    1.68    86.2   47     41        N
# 346   44    Male       84          202    1.73    71.2   37     33        N
# 347   40  Female       85          169    1.65    81.6   44     40        N
#
#      waist_hip_ratio age_group        bmi  obesity
# ...

# %%
order_df = pd.read_csv('data/order.csv', parse_dates=['order_time'])

# %%
order_df.head()
# Out:
#            order_time              category  \
# 0 2015-01-01 04:54:00                Cleats
# 1                 NaT        Men's Footwear
# 2 2015-01-01 02:27:00  Indoor/Outdoor Games
# 3 2015-01-01 19:58:00           Golf Gloves
# 4 2015-01-01 03:51:00      Camping & Hiking
#
#                                     product_name   price  quantity   sales  \
# 0               Perfect Fitness Perfect Rip Deck   59.99         3  179.97
# 1        Nike Men's CJ Elite 2 TD Football Cleat  129.99         1  129.99
# 2               O'Brien Men's Neoprene Life Vest   49.98         4  199.92
# 3                        Clicgear 8.0 Shoe Brush    9.99         2   19.98
# 4  Diamondback Women's Serene Classic Comfort Bi  299.98         1  299.98
#
#    days_for_shipping(expected)        shipping_time
# 0                            6  2015-01-07 19:07:00
# 1                            6  2015-01-04 09:47:00
# 2                            6  2015-01-05 13:15:00
# ...

# %%
order_df['order_time'] = pd.to_datetime(order_df['order_time'])

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18050 entries, 0 to 18049
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   order_time                   18049 non-null  datetime64[ns]
#  1   category                     18050 non-null  object
#  2   product_name                 18050 non-null  object
#  3   price                        18050 non-null  float64
#  4   quantity                     18050 non-null  int64
#  5   sales                        18050 non-null  float64
#  6   days_for_shipping(expected)  18050 non-null  int64
#  7   shipping_time                18050 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 1.1+ MB

# %%
order_df['order_time'].dt.date
# Out:
# 0        2015-01-01
# 1               NaT
# 2        2015-01-01
# 3        2015-01-01
# 4        2015-01-01
#             ...
# 18045    2018-01-31
# 18046    2018-01-31
# 18047    2018-01-31
# 18048    2018-01-31
# 18049    2018-01-31
# Name: order_time, Length: 18050, dtype: object

# %%
# order_df['order_time'] = order_df['order_time'].strftime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [229], line 1
# ----> 1 order_df['order_time'] = order_df['order_time'].strftime()
#
# File c:\Users\kangdongwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strftime'

# %%
delivery_df = pd.read_csv('data/delivery.csv', parse_dates=['order_time'])

# %%
delivery_df
# Out:
#              order_time  distance  time_taken  num_of_deliveries  charge
# 0   2022-10-17 18:34:00       3.9          21                  1    4.68
# 1   2022-10-17 18:35:00       5.2          24                  1    7.02
# 2   2022-10-17 18:36:00       8.4          36                  2    9.53
# 3   2022-10-17 18:37:00       3.6          17                  1    6.21
# 4   2022-10-17 18:41:00       2.6          15                  1    2.44
# ..                  ...       ...         ...                ...     ...
# 104 2022-10-23 19:28:00       6.4          37                  1    5.01
# 105 2022-10-23 19:28:00       3.9          26                  2    7.34
# 106 2022-10-23 19:48:00       3.3          21                  1    3.83
# 107 2022-10-23 19:49:00       5.8          22                  1    5.80
# 108 2022-10-23 19:50:00       4.4          19                  1    7.78
#
# [109 rows x 5 columns]
