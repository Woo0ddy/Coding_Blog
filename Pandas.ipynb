# %%
import pandas as pd

# %%
exam = pd.read_csv('data/exam.csv')

# %%
exam
# Out:
#      math_score  science_score  english_score second_lang
# 0          45.0           68.0           68.0     Chinese
# 1          80.0           44.0           78.0    Japanese
# 2          37.5           50.0           78.0     Chinese
# 3          57.5           56.0           78.0     Russian
# 4          45.0           68.0           82.0     Chinese
# ..          ...            ...            ...         ...
# 195        45.0           50.0           72.0      German
# 196        52.5           44.0           82.0      German
# 197        57.5           54.0           84.0     Chinese
# 198        50.0           54.0           74.0      French
# 199        65.0           54.0           84.0    Japanese
#
# [200 rows x 4 columns]

# %%
exam.describe()
# Out:
#        math_score  science_score  english_score
# count  200.000000      200.00000     200.000000
# mean    52.830000       54.98750      77.547500
# std     12.961912        9.42178       9.165507
# min     15.000000       20.00000      25.000000
# 25%     45.000000       48.00000      72.000000
# 50%     52.500000       56.00000      78.000000
# 75%     60.000000       62.00000      84.000000
# max     95.000000       90.00000      94.000000

# %%
exam.describe(include='all')
# Out:
#         math_score  science_score  english_score second_lang
# count   200.000000      200.00000     200.000000         200
# unique         NaN            NaN            NaN           5
# top            NaN            NaN            NaN     Chinese
# freq           NaN            NaN            NaN          65
# mean     52.830000       54.98750      77.547500         NaN
# std      12.961912        9.42178       9.165507         NaN
# min      15.000000       20.00000      25.000000         NaN
# 25%      45.000000       48.00000      72.000000         NaN
# 50%      52.500000       56.00000      78.000000         NaN
# 75%      60.000000       62.00000      84.000000         NaN
# max      95.000000       90.00000      94.000000         NaN

# %%
import matplotlib.pyplot as plt

# %%
exam['math_score'].plot(kind='box')
# Out:
# <Axes: >

# %%
q1 = exam['math_score'].quantile(0.25)

# %%
q1
# Out:
# 45.0

# %%
q3 = exam['math_score'].quantile(0.75)

# %%
q3
# Out:
# 60.0

# %%
iqr = q3 - q1
iqr
# Out:
# 15.0

# %%
q1 - 1.5 * iqr
# Out:
# 22.5

# %%
q3 + 1.5 * iqr
# Out:
# 82.5

# %%
df = pd.read_csv('data/starbucks.csv')

# %%
df
# Out:
#                        category  \
# 0       Classic Espresso Drinks
# 1     Signature Espresso Drinks
# 2       Classic Espresso Drinks
# 3    Frappuccino® Blended Crème
# 4       Classic Espresso Drinks
# ..                          ...
# 214     Classic Espresso Drinks
# 215                      Coffee
# 216   Signature Espresso Drinks
# 217   Signature Espresso Drinks
# 218            Tazo® Tea Drinks
#
#                                           beverage              option  \
# 0                       Skinny Latte (Any Flavour)  Grande Nonfat Milk
# 1                                Caramel Macchiato  Grande Nonfat Milk
# 2                       Skinny Latte (Any Flavour)   Short Nonfat Milk
# 3     Strawberries & Crème (Without Whipped Cream)  Grande Nonfat Milk
# 4                                      Caffè Latte  Grande Nonfat Milk
# ..                                             ...                 ...
# 214                                     Cappuccino    Tall Nonfat Milk
# ...

# %%
df['protein(g)'].plot(kind='box')
# Out:
# <Axes: >

# %%
q1 = df['protein(g)'].quantile(0.25)

# %%
df['protein(g)'].quantile(0.5)
# Out:
# 6.0

# %%
q3 = df['protein(g)'].quantile(0.75)

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 6.0

# %%
q3 + 1.5 * iqr
# Out:
# 19.0

# %%
df['protein(g)'].max()
# Out:
# 20.0

# %%
df.describe()
# Out:
#          calories  total_carbohydrates(g)  total_fat(g)  protein(g)  \
# count  219.000000              219.000000    219.000000  219.000000
# mean   201.584475              137.374429      3.074886    7.294521
# std    102.353614               80.605714      3.000590    4.790546
# min      3.000000                0.000000      0.000000    0.000000
# 25%    125.000000               80.000000      0.200000    4.000000
# 50%    190.000000              130.000000      2.500000    6.000000
# 75%    270.000000              180.000000      5.000000   10.000000
# max    510.000000              340.000000     15.000000   20.000000
#
#        cholesterol(mg)  caffeine(mg)
# count       219.000000    219.000000
# mean         37.296804     89.520548
# std          20.926664     64.726831
# min           0.000000      0.000000
# 25%          21.000000     50.000000
# 50%          36.000000     75.000000
# 75%          53.000000    142.500000
# max          90.000000    410.000000

# %%
df = pd.read_csv('data/body.csv')

# %%
df
# Out:
#      height  weight
# 0     188.3    85.8
# 1     176.2    78.0
# 2     175.9    75.6
# 3     181.1    85.1
# 4     182.6    82.3
# ..      ...     ...
# 495   172.0    70.0
# 496   169.6    83.0
# 497   163.3    68.6
# 498   185.7    95.6
# 499   167.7    76.7
#
# [500 rows x 2 columns]

# %%
df['height'].plot(kind='hist', bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.describe()
# Out:
#           height      weight
# count  500.00000  500.000000
# mean   173.26280   75.542600
# std      7.27484    7.303482
# min    151.30000   54.100000
# 25%    168.50000   70.775000
# 50%    172.95000   75.300000
# 75%    178.22500   80.650000
# max    195.80000   95.600000

# %%
df = pd.read_csv('data/car.csv')

# %%
df['price'].plot(kind='hist', bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['manufacturer'] == 'HYUNDAI']['price'].plot(kind='hist', bins= 15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#         manufacturer   category fuel_type  engine_volume  mileage  price
# 0            HYUNDAI       Jeep    Petrol            2.0    36800  36065
# 1             TOYOTA      Sedan    Petrol            2.5   107000  15053
# 2             NISSAN       Jeep    Petrol            1.6   108222   7527
# 3                BMW       Jeep    Diesel            3.0    18000  15681
# 4      MERCEDES-BENZ  Hatchback    Petrol            1.7   160000  13485
# ...              ...        ...       ...            ...      ...    ...
# 12014         TOYOTA  Hatchback    Hybrid            1.5   181474  14831
# 12015      CHEVROLET       Jeep    Diesel            2.0    70922  41055
# 12016        HYUNDAI       Jeep    Diesel            2.0   273371  27858
# 12017          LEXUS       Jeep       LPG            4.7   170000  34497
# 12018  MERCEDES-BENZ      Coupe    Petrol            2.3   157000   7213
#
# [12019 rows x 6 columns]

# %%
df.describe()
# Out:
#        engine_volume        mileage          price
# count   12019.000000   12019.000000   12019.000000
# mean        2.270239  131629.232798   22585.734504
# std         0.824561   85761.569484   18133.404347
# min         0.000000       0.000000    5018.000000
# 25%         1.800000   70000.000000   11604.000000
# 50%         2.000000  120950.000000   17249.000000
# 75%         2.500000  177932.000000   26971.000000
# max         7.300000  498815.000000  297930.000000

# %%
df['engine_volume'].var()   #분산
# Out:
# 0.6799005171140591

# %%
a = 177
b = 183
c = 160
d = 164
mean = (a+b+c+d)/4
((a-mean)**2 + (b-mean)**2 + (c-mean)**2 + (d-mean)**2) / 4
# Out:
# 87.5

# %%
df
# Out:
#         manufacturer   category fuel_type  engine_volume  mileage  price
# 0            HYUNDAI       Jeep    Petrol            2.0    36800  36065
# 1             TOYOTA      Sedan    Petrol            2.5   107000  15053
# 2             NISSAN       Jeep    Petrol            1.6   108222   7527
# 3                BMW       Jeep    Diesel            3.0    18000  15681
# 4      MERCEDES-BENZ  Hatchback    Petrol            1.7   160000  13485
# ...              ...        ...       ...            ...      ...    ...
# 12014         TOYOTA  Hatchback    Hybrid            1.5   181474  14831
# 12015      CHEVROLET       Jeep    Diesel            2.0    70922  41055
# 12016        HYUNDAI       Jeep    Diesel            2.0   273371  27858
# 12017          LEXUS       Jeep       LPG            4.7   170000  34497
# 12018  MERCEDES-BENZ      Coupe    Petrol            2.3   157000   7213
#
# [12019 rows x 6 columns]

# %%
df['new_name'] = df['price'].cumsum() #해당 값들을 누적해서 기록(우상향 그래프)

# %%
df
# Out:
#         manufacturer   category fuel_type  engine_volume  mileage  price  \
# 0            HYUNDAI       Jeep    Petrol            2.0    36800  36065
# 1             TOYOTA      Sedan    Petrol            2.5   107000  15053
# 2             NISSAN       Jeep    Petrol            1.6   108222   7527
# 3                BMW       Jeep    Diesel            3.0    18000  15681
# 4      MERCEDES-BENZ  Hatchback    Petrol            1.7   160000  13485
# ...              ...        ...       ...            ...      ...    ...
# 12014         TOYOTA  Hatchback    Hybrid            1.5   181474  14831
# 12015      CHEVROLET       Jeep    Diesel            2.0    70922  41055
# 12016        HYUNDAI       Jeep    Diesel            2.0   273371  27858
# 12017          LEXUS       Jeep       LPG            4.7   170000  34497
# 12018  MERCEDES-BENZ      Coupe    Petrol            2.3   157000   7213
#
#         new_name
# 0          36065
# 1          51118
# 2          58645
# 3          74326
# ...

# %%
bike_df = pd.read_csv('data/bike.csv')

# %%
bike_df
# Out:
#      month  day quarter day_of_week  workingday  holiday  temperature  \
# 0        1    1      1Q         SUN           0        0         21.4
# 1        1    2      1Q         MON           0        1         15.0
# 2        1    3      1Q         TUE           1        0          7.6
# 3        1    4      1Q         WED           1        0          0.4
# 4        1    5      1Q         THU           1        0         14.2
# ..     ...  ...     ...         ...         ...      ...          ...
# 361     12   27      4Q         THU           1        0         10.0
# 362     12   28      4Q         FRI           1        0         14.0
# 363     12   29      4Q         SAT           0        0         14.9
# 364     12   30      4Q         SUN           0        0         16.5
# 365     12   31      4Q         MON           1        0          3.5
#
#      humidity  windspeed  registered  casual  total
# 0          72         12        1608     686   2294
# ...

# %%
import seaborn as sns

# %%
sns.barplot(data=bike_df, x='month', y='total', errorbar=None, hue='workingday')
# Out:
# <Axes: xlabel='month', ylabel='total'>

# %%
sns.histplot(multiple='stack') # multiple='stack' 각 라인에 쌓아서 보여줌
